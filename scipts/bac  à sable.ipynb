# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib nbagg

# %%
import raman_parser as rp
import os

# %%
map1 = rp.raman_mapping_xy(r'S:/300-Projets_Transverses/300.56-Solflex/raman_data/20190701_maps/txt/SOP_200nm_110_Furu_xy_01.txt')

# %%
map1.plot_biax()
# Out:
# mean biax strain = -0.0214 +- 0.0058

# %%
plt.hist(map1.eps_biax,5)
plt.xlabel('$\epsilon$ %')
# Out:
# Text(0.5, 0, '$\\epsilon$ %')

# %%
os.chdir(r"S:\300-Projets_Transverses\300.56-Solflex\raman_data\20190705_new\txt")

# %%
ls
# Out:
#  Le volume dans le lecteur S s'appelle share
#  Le num‚ro de s‚rie du volume est 809D-E460
#
#  R‚pertoire de S:\300-Projets_Transverses\300.56-Solflex\raman_data\20190705_new\txt
#
# 05/07/2019  12:36           210ÿ876 P1_center_01.txt
# 05/07/2019  12:36           210ÿ930 P1_edge_01.txt
# 05/07/2019  12:36           210ÿ727 P2_center_01.txt
# 05/07/2019  12:36           211ÿ002 P2_edge_01.txt
# 05/07/2019  12:36           210ÿ959 P3_center_01.txt
# 05/07/2019  12:36           210ÿ976 P3_edge_01.txt
# 05/07/2019  12:36           210ÿ916 P4_center_01.txt
# 05/07/2019  12:36           210ÿ964 P4_edge_01.txt
# 05/07/2019  12:36           210ÿ986 P5_center_01.txt
# 05/07/2019  12:36           210ÿ980 P5_edge_01.txt
# 05/07/2019  12:36            18ÿ388 Si_ref_begin_01.txt
# 05/07/2019  12:36            18ÿ380 Si_ref_begin_02.txt
# 05/07/2019  12:36            17ÿ888 Si_ref_begin_03.txt
# 05/07/2019  12:36            17ÿ860 Si_ref_end_01.txt
# ...

# %%
ref_start = rp.raman_spectrum(r"Si_ref_begin_03.txt")
ref_start.plot()
ref_end  = rp.raman_spectrum(r"Si_ref_end_02.txt")
ref_end.plot()
print(ref_start.peak_pos,ref_end.peak_pos)
print("drift linear speed approx {:f} cm^-1/h".format(
    (
        (ref_end.peak_pos-ref_start.peak_pos)/(ref_end.epoch-ref_start.epoch))*3600))
# Out:
# 520.6633776562661 520.4041700517542
# drift linear speed approx -0.124652 cm^-1/h

# %%
ref_start.popt
# Out:
# array([ 520.66337766, 1405.6320938 ,   -1.40713813,    3.7968357 ])

# %%
ref_end.popt
# Out:
# array([5.20404170e+02, 1.45661632e+03, 1.40268635e+00, 3.91044691e+00])

# %%
r_object_center = []
r_object_edge = []
center_mean = []
center_std = []
edge_mean = []
edge_std = []
for iii in np.arange(5):
    print(iii)
    r_object_center.append(rp.raman_mapping_xy(r"P{:d}_center_01.txt".format(iii+1)))
    r_object_center[iii].strain_biax()
    r_object_center[iii].plot_biax()
    center_mean.append(r_object_center[iii].eps_biax_mean)
    center_std.append(r_object_center[iii].eps_biax_std)
    r_object_edge.append(rp.raman_mapping_xy(r"P{:d}_edge_01.txt".format(iii+1)))
    r_object_edge[iii].strain_biax()
    r_object_edge[iii].plot_biax()
    edge_mean.append(r_object_edge[iii].eps_biax_mean)
    edge_std.append(r_object_edge[iii].eps_biax_std)
# Out:
# 0
# mean biax strain = -0.0561 +- 0.0022
# mean biax strain = -0.0593 +- 0.0027
# 1
# mean biax strain = -0.0517 +- 0.0041
# mean biax strain = -0.0622 +- 0.0042
# 2
# mean biax strain = -0.0562 +- 0.0022
# mean biax strain = -0.0524 +- 0.0057
# 3
# mean biax strain = -0.0389 +- 0.0020
# mean biax strain = -0.0442 +- 0.0031
# 4
# mean biax strain = -0.0381 +- 0.0042
# mean biax strain = -0.0469 +- 0.0028

# %%
plt.figure()
plt.errorbar(np.arange(5), center_mean, center_std,label = 'center',marker='o')
plt.errorbar(np.arange(5), edge_mean,edge_std, label='edge',marker = 'o')
plt.legend()
plt.show()

# %%
r_object_center[1].plot_fit_raw()

# %%
r_object_center[0].plot_fit_raw()

# %%
import raman_parser as rp

# %%
r_object_center = []
r_object_edge = []
center_mean = []
center_std = []
edge_mean = []
edge_std = []
for iii in np.arange(5):
    print(iii)
    r_object_center.append(rp.raman_mapping_xy(r"P{:d}_center_01.txt".format(iii+1)))
    r_object_center[iii].strain_biax()
    r_object_center[iii].plot_biax()
    center_mean.append(r_object_center[iii].eps_biax_mean)
    center_std.append(r_object_center[iii].eps_biax_std)
    r_object_edge.append(rp.raman_mapping_xy(r"P{:d}_edge_01.txt".format(iii+1)))
    r_object_edge[iii].strain_biax()
    r_object_edge[iii].plot_biax()
    edge_mean.append(r_object_edge[iii].eps_biax_mean)
    edge_std.append(r_object_edge[iii].eps_biax_std)
# Out:
# 0
# mean biax strain = -0.0561 +- 0.0022
# mean biax strain = -0.0593 +- 0.0027
# 1
# mean biax strain = -0.0517 +- 0.0041
# mean biax strain = -0.0622 +- 0.0042
# 2
# mean biax strain = -0.0562 +- 0.0022
# mean biax strain = -0.0524 +- 0.0057
# 3
# mean biax strain = -0.0389 +- 0.0020
# mean biax strain = -0.0442 +- 0.0031
# 4
# mean biax strain = -0.0381 +- 0.0042
# mean biax strain = -0.0469 +- 0.0028

# %%
r_object_center[1].plot_fit_raw()

# %%
r_object_center[1].peak_shift_array
# Out:
# array([[0.37964488, 0.40778728, 0.33396496, 0.33497371, 0.36776962],
#        [0.34329068, 0.36468272, 0.36710485, 0.35530236, 0.3536128 ],
#        [0.35142211, 0.37678555, 0.35838329, 0.42541496, 0.45663694],
#        [0.39831057, 0.37925509, 0.41043979, 0.37650798, 0.35901389],
#        [0.38760279, 0.3895441 , 0.42160528, 0.37086872, 0.41281504]])

# %%
os.chdir(r"S:\300-Projets_Transverses\300.56-Solflex\raman_data\20190701_maps\txt")

# %%
ref_start1 = rp.raman_spectrum("Si_ref_begin_02.txt")
ref_start1.plot()
ref_end1 = rp.raman_spectrum("Si_ref_end_01.txt")
ref_end1.plot()
print(ref_start1.peak_pos,ref_end1.peak_pos)
# Out:
# 520.6942154018894 520.324850639555

# %%
map1 = rp.raman_mapping_xy("SOP_200nm_110_Furu_xy_01.txt") 
map2 = rp.raman_mapping_xy("SOP_200nm_110_Furu_xy_02.txt")
map3 = rp.raman_mapping_xy("SOP_200nm_circle_Furu_xy_01.txt")

# %%
map1.plot_map_shift()
map2.plot_map_shift()
map3.plot_map_shift()

# %%
map1.plot_biax()
map2.plot_biax()
map3.plot_biax()
# Out:
# mean biax strain = -0.0214 +- 0.0058
# mean biax strain = -0.0295 +- 0.0061
# mean biax strain = -0.0337 +- 0.0086

# %%
map1.plot_fit_raw()
map2.plot_fit_raw()
map3.plot_fit_raw()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
